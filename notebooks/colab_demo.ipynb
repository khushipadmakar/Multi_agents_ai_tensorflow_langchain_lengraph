# %% [markdown]
# # Multi-Agent Colab Demo
# This notebook trains lightweight TensorFlow models, exports them, and calls the FastAPI backend.

# %%
# !pip install -q -e .
from multi_agent_ml_ops.agents.supervisor import build_graph

graph = build_graph()
print('graph ready')
